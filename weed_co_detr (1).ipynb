# %%
# !rm -rf /content/sample_data
# !pip install --upgrade --no-cache-dir gdown

#https://drive.google.com/file/d/1rhyXN1ia2Fg3TFdkvFymy2F8VCGpE5Hv/view?usp=drive_link
# !gdown https://drive.google.com/uc?id=1rhyXN1ia2Fg3TFdkvFymy2F8VCGpE5Hv

#https://drive.google.com/file/d/13bAMyCa3kPuFPVAu39Bq39DgiEqQySS2/view?usp=sharing
# !gdown https://drive.google.com/uc?id=13bAMyCa3kPuFPVAu39Bq39DgiEqQySS2

# !unzip /content/UAVWeedSegmentation-main.zip
# !unzip /content/sorghum_fields.zip
# !rm -rf /content/*.zip

# !mv "/content/Data for Deep learning-based early weed segmentation using motion blurred UAV images of sorghum fields" "data"
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.7.3)
# Collecting gdown
#   Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.7.3
#     Uninstalling gdown-4.7.3:
#       Successfully uninstalled gdown-4.7.3
# Successfully installed gdown-5.1.0
# Downloading...
# From (original): https://drive.google.com/uc?id=1rhyXN1ia2Fg3TFdkvFymy2F8VCGpE5Hv
# From (redirected): https://drive.google.com/uc?id=1rhyXN1ia2Fg3TFdkvFymy2F8VCGpE5Hv&confirm=t&uuid=ad3bab9c-891b-4d0d-974c-2cdedb69dbb8
# To: /content/UAVWeedSegmentation-main.zip
# 100% 162M/162M [00:00<00:00, 184MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=13bAMyCa3kPuFPVAu39Bq39DgiEqQySS2
# From (redirected): https://drive.google.com/uc?id=13bAMyCa3kPuFPVAu39Bq39DgiEqQySS2&confirm=t&uuid=0d4e7472-85b0-4357-b551-c9999bffd946
# To: /content/sorghum_fields.zip
# 100% 294M/294M [00:01<00:00, 191MB/s]
# Archive:  /content/UAVWeedSegmentation-main.zip
# 514a08d1aca6bf3d04fe95844e987d8dba0343d7
#    creating: UAVWeedSegmentation-main/
#   inflating: UAVWeedSegmentation-main/.gitignore
#   inflating: UAVWeedSegmentation-main/LICENSE
#   inflating: UAVWeedSegmentation-main/README.md
#   inflating: UAVWeedSegmentation-main/compare_predictions.py
#   inflating: UAVWeedSegmentation-main/compare_studies.py
#    creating: UAVWeedSegmentation-main/data/
#    creating: UAVWeedSegmentation-main/data/test/
#    creating: UAVWeedSegmentation-main/data/test/img/
#   inflating: UAVWeedSegmentation-main/data/test/img/test_01.jpg
#   inflating: UAVWeedSegmentation-main/data/test/img/test_02.jpg
#   inflating: UAVWeedSegmentation-main/data/test/img/test_03.jpg
#    creating: UAVWeedSegmentation-main/data/test/msk/
#   inflating: UAVWeedSegmentation-main/data/test/msk/test_01.png
#   inflating: UAVWeedSegmentation-main/data/test/msk/test_02.png
#   inflating: UAVWeedSegmentation-main/data/test/msk/test_03.png
#    creating: UAVWeedSegmentation-main/data/test_different_bbch/
#    creating: UAVWeedSegmentation-main/data/test_different_bbch/img/
#   inflating: UAVWeedSegmentation-main/data/test_different_bbch/img/bbch15_img.jpg
#   inflating: UAVWeedSegmentation-main/data/test_different_bbch/img/bbch19_img.jpg
#    creating: UAVWeedSegmentation-main/data/test_different_bbch/msk/
#   inflating: UAVWeedSegmentation-main/data/test_different_bbch/msk/bbch15_msk.png
#   inflating: UAVWeedSegmentation-main/data/test_different_bbch/msk/bbch19_msk.png
#    creating: UAVWeedSegmentation-main/data/trainval/
#    creating: UAVWeedSegmentation-main/data/trainval/img/
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_00.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_01.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_02.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_03.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_04.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_05.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_06.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_07.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_08.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_09.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_10.jpg
#   inflating: UAVWeedSegmentation-main/data/trainval/img/trainval_11.jpg
#    creating: UAVWeedSegmentation-main/data/trainval/msk/
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_00.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_01.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_02.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_03.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_04.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_05.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_06.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_07.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_08.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_09.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_10.png
#   inflating: UAVWeedSegmentation-main/data/trainval/msk/trainval_11.png
#   inflating: UAVWeedSegmentation-main/predict_testset.py
#    creating: UAVWeedSegmentation-main/readme_fig/
#   inflating: UAVWeedSegmentation-main/readme_fig/cm_subset_test.jpg
#   inflating: UAVWeedSegmentation-main/readme_fig/example_pred.jpg
#   inflating: UAVWeedSegmentation-main/readme_fig/supfigure4.jpg
#   inflating: UAVWeedSegmentation-main/requirements.txt
#    creating: UAVWeedSegmentation-main/results/
#    creating: UAVWeedSegmentation-main/results/predictions/
#   inflating: UAVWeedSegmentation-main/results/predictions/cm_subset_test.pdf
#   inflating: UAVWeedSegmentation-main/results/predictions/cm_subset_test_different_bbch_bbch_15.png
#   inflating: UAVWeedSegmentation-main/results/predictions/cm_subset_test_different_bbch_bbch_19.png
#    creating: UAVWeedSegmentation-main/results/predictions/test/
#   inflating: UAVWeedSegmentation-main/results/predictions/test/test_01_pred.png
#   inflating: UAVWeedSegmentation-main/results/predictions/test/test_02_pred.png
#   inflating: UAVWeedSegmentation-main/results/predictions/test/test_03_pred.png
#    creating: UAVWeedSegmentation-main/results/predictions/test_different_bbch/
#   inflating: UAVWeedSegmentation-main/results/predictions/test_different_bbch/bbch15_img_pred.png
#   inflating: UAVWeedSegmentation-main/results/predictions/test_different_bbch/bbch19_img_pred.png
#   inflating: UAVWeedSegmentation-main/retrain.py
#   inflating: UAVWeedSegmentation-main/save_patches.py
#   inflating: UAVWeedSegmentation-main/small_training.py
#   inflating: UAVWeedSegmentation-main/train.py
#    creating: UAVWeedSegmentation-main/utils/
#  extracting: UAVWeedSegmentation-main/utils/__init__.py
#   inflating: UAVWeedSegmentation-main/utils/compare.py
#   inflating: UAVWeedSegmentation-main/utils/dataset.py
#   inflating: UAVWeedSegmentation-main/utils/manual_dlplus.py
#   inflating: UAVWeedSegmentation-main/utils/manual_fcn.py
#   inflating: UAVWeedSegmentation-main/utils/manual_resnet.py
#   inflating: UAVWeedSegmentation-main/utils/manual_unet.py
#   inflating: UAVWeedSegmentation-main/utils/parser.py
#   inflating: UAVWeedSegmentation-main/utils/patch_utils.py
#   inflating: UAVWeedSegmentation-main/utils/predict.py
#   inflating: UAVWeedSegmentation-main/utils/studies.py
#   inflating: UAVWeedSegmentation-main/utils/train.py
# Archive:  /content/sorghum_fields.zip
#   inflating: Data for Deep learning-based early weed segmentation using motion blurred UAV images of sorghum fields/data.zip
#   inflating: Data for Deep learning-based early weed segmentation using motion blurred UAV images of sorghum fields/model_unet_resnet34_dil0_bilin1_retrained.zip

# %%
# !unzip /content/data/model_unet_resnet34_dil0_bilin1_retrained.zip
# Out:
# Archive:  /content/data/model_unet_resnet34_dil0_bilin1_retrained.zip
#   inflating: model_unet_resnet34_dil0_bilin1_retrained.pt

# %%
# !mkdir /content/UAVWeedSegmentation-main/models
# !mv "/content/model_unet_resnet34_dil0_bilin1_retrained.pt" "/content/UAVWeedSegmentation-main/models/model_unet_resnet34_dil0_bilin1_retrained.pt"
# !rm -rf /content/data

# %%
# %cd /content/UAVWeedSegmentation-main
# Out:
# /content/UAVWeedSegmentation-main

# %%
# !pip install -r requirements.txt
# Out:
# Collecting albumentations==1.1.0 (from -r requirements.txt (line 1))
#   Downloading albumentations-1.1.0-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 1.5 MB/s eta 0:00:00
# Collecting alembic==1.7.6 (from -r requirements.txt (line 2))
#   Downloading alembic-1.7.6-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.4/210.4 kB 4.7 MB/s eta 0:00:00
# Collecting attrs==21.4.0 (from -r requirements.txt (line 3))
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 8.4 MB/s eta 0:00:00
# Collecting autopage==0.5.0 (from -r requirements.txt (line 4))
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Collecting cliff==3.10.0 (from -r requirements.txt (line 5))
#   Downloading cliff-3.10.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 11.0 MB/s eta 0:00:00
# Collecting cmaes==0.8.2 (from -r requirements.txt (line 6))
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Collecting cmd2==2.3.3 (from -r requirements.txt (line 7))
#   Downloading cmd2-2.3.3-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.1/149.1 kB 14.2 MB/s eta 0:00:00
# Collecting colorlog==6.6.0 (from -r requirements.txt (line 8))
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Collecting cycler==0.11.0 (from -r requirements.txt (line 9))
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools==4.29.1 (from -r requirements.txt (line 10))
#   Downloading fonttools-4.29.1-py3-none-any.whl (895 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 895.5/895.5 kB 10.7 MB/s eta 0:00:00
# Collecting greenlet==1.1.2 (from -r requirements.txt (line 11))
#   Downloading greenlet-1.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 8.1 MB/s eta 0:00:00
# Collecting imageio==2.14.1 (from -r requirements.txt (line 12))
#   Downloading imageio-2.14.1-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 7.9 MB/s eta 0:00:00
# Collecting importlib-metadata==4.10.1 (from -r requirements.txt (line 13))
#   Downloading importlib_metadata-4.10.1-py3-none-any.whl (17 kB)
# Collecting importlib-resources==5.4.0 (from -r requirements.txt (line 14))
#   Downloading importlib_resources-5.4.0-py3-none-any.whl (28 kB)
# Collecting joblib==1.1.0 (from -r requirements.txt (line 15))
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 7.2 MB/s eta 0:00:00
# Collecting kiwisolver==1.3.2 (from -r requirements.txt (line 16))
#   Downloading kiwisolver-1.3.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 8.1 MB/s eta 0:00:00
# Collecting kornia==0.6.3 (from -r requirements.txt (line 17))
#   Downloading kornia-0.6.3-py2.py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.8/474.8 kB 8.2 MB/s eta 0:00:00
# Collecting Mako==1.1.6 (from -r requirements.txt (line 18))
#   Downloading Mako-1.1.6-py2.py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 7.3 MB/s eta 0:00:00
# Collecting MarkupSafe==2.0.1 (from -r requirements.txt (line 19))
#   Downloading MarkupSafe-2.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting matplotlib==3.5.1 (from -r requirements.txt (line 20))
#   Downloading matplotlib-3.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 8.4 MB/s eta 0:00:00
# Collecting networkx==2.6.3 (from -r requirements.txt (line 21))
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 9.7 MB/s eta 0:00:00
# Collecting numpy==1.22.1 (from -r requirements.txt (line 22))
#   Downloading numpy-1.22.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 5.0 MB/s eta 0:00:00
# Collecting opencv-python==4.5.5.62 (from -r requirements.txt (line 23))
#   Downloading opencv_python-4.5.5.62-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 1.8 MB/s eta 0:00:00
# Collecting opencv-python-headless==4.5.5.62 (from -r requirements.txt (line 24))
#   Downloading opencv_python_headless-4.5.5.62-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 1.6 MB/s eta 0:00:00
# Collecting optuna==2.10.0 (from -r requirements.txt (line 25))
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.2/308.2 kB 2.3 MB/s eta 0:00:00
# Collecting packaging==21.3 (from -r requirements.txt (line 26))
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 2.1 MB/s eta 0:00:00
# Collecting pandas==1.4.0 (from -r requirements.txt (line 27))
#   Downloading pandas-1.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 2.5 MB/s eta 0:00:00
# Collecting patchify==0.2.3 (from -r requirements.txt (line 28))
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Collecting pbr==5.8.0 (from -r requirements.txt (line 29))
#   Downloading pbr-5.8.0-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 kB 1.8 MB/s eta 0:00:00
# Collecting Pillow==9.0.1 (from -r requirements.txt (line 30))
#   Downloading Pillow-9.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 2.4 MB/s eta 0:00:00
# Collecting prettytable==3.0.0 (from -r requirements.txt (line 31))
#   Downloading prettytable-3.0.0-py3-none-any.whl (24 kB)
# Collecting pyparsing==3.0.7 (from -r requirements.txt (line 32))
#   Downloading pyparsing-3.0.7-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.0/98.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: pyperclip==1.8.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 33)) (1.8.2)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 34)) (2.8.2)
# Collecting pytz==2021.3 (from -r requirements.txt (line 35))
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 kB 2.3 MB/s eta 0:00:00
# Collecting PyWavelets==1.2.0 (from -r requirements.txt (line 36))
#   Downloading PyWavelets-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 2.8 MB/s eta 0:00:00
# Collecting PyYAML==6.0 (from -r requirements.txt (line 37))
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: qudida==0.0.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 38)) (0.0.4)
# Collecting scikit-image==0.19.1 (from -r requirements.txt (line 39))
#   Downloading scikit_image-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 4.1 MB/s eta 0:00:00
# Collecting scikit-learn==1.0.2 (from -r requirements.txt (line 40))
#   Downloading scikit_learn-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 3.4 MB/s eta 0:00:00
# Collecting scipy==1.7.3 (from -r requirements.txt (line 41))
#   Downloading scipy-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 42)) (1.16.0)
# Collecting SQLAlchemy==1.4.31 (from -r requirements.txt (line 43))
#   Downloading SQLAlchemy-1.4.31-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.6 MB/s eta 0:00:00
# Collecting stevedore==3.5.0 (from -r requirements.txt (line 44))
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.3 MB/s eta 0:00:00
# Collecting threadpoolctl==3.1.0 (from -r requirements.txt (line 45))
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting tifffile==2021.11.2 (from -r requirements.txt (line 46))
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 2.8 MB/s eta 0:00:00
# Collecting tqdm==4.62.3 (from -r requirements.txt (line 47))
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 3.2 MB/s eta 0:00:00
# Collecting typing_extensions==4.0.1 (from -r requirements.txt (line 48))
#   Downloading typing_extensions-4.0.1-py3-none-any.whl (22 kB)
# Collecting wcwidth==0.2.5 (from -r requirements.txt (line 49))
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting zipp==3.7.0 (from -r requirements.txt (line 50))
#   Downloading zipp-3.7.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from kornia==0.6.3->-r requirements.txt (line 17)) (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->kornia==0.6.3->-r requirements.txt (line 17)) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->kornia==0.6.3->-r requirements.txt (line 17)) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->kornia==0.6.3->-r requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->kornia==0.6.3->-r requirements.txt (line 17)) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->kornia==0.6.3->-r requirements.txt (line 17)) (2.1.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->kornia==0.6.3->-r requirements.txt (line 17)) (1.3.0)
# Installing collected packages: wcwidth, pytz, zipp, typing_extensions, tqdm, threadpoolctl, PyYAML, pyparsing, prettytable, Pillow, pbr, numpy, networkx, MarkupSafe, kiwisolver, joblib, importlib-resources, greenlet, fonttools, cycler, colorlog, autopage, attrs, tifffile, stevedore, SQLAlchemy, scipy, PyWavelets, patchify, pandas, packaging, opencv-python-headless, opencv-python, Mako, importlib-metadata, imageio, cmd2, cmaes, scikit-learn, scikit-image, matplotlib, cliff, alembic, optuna, kornia, albumentations
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.13
#     Uninstalling wcwidth-0.2.13:
#       Successfully uninstalled wcwidth-0.2.13
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.4
#     Uninstalling pytz-2023.4:
#       Successfully uninstalled pytz-2023.4
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.17.0
#     Uninstalling zipp-3.17.0:
#       Successfully uninstalled zipp-3.17.0
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.3.0
#     Uninstalling threadpoolctl-3.3.0:
#       Successfully uninstalled threadpoolctl-3.3.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.9.0
#     Uninstalling prettytable-3.9.0:
#       Successfully uninstalled prettytable-3.9.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.5
#     Uninstalling kiwisolver-1.4.5:
#       Successfully uninstalled kiwisolver-1.4.5
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 6.1.1
#     Uninstalling importlib-resources-6.1.1:
#       Successfully uninstalled importlib-resources-6.1.1
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.0.3
#     Uninstalling greenlet-3.0.3:
#       Successfully uninstalled greenlet-3.0.3
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.49.0
#     Uninstalling fonttools-4.49.0:
#       Successfully uninstalled fonttools-4.49.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#   Attempting uninstall: tifffile
#     Found existing installation: tifffile 2024.2.12
#     Uninstalling tifffile-2024.2.12:
#       Successfully uninstalled tifffile-2024.2.12
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.27
#     Uninstalling SQLAlchemy-2.0.27:
#       Successfully uninstalled SQLAlchemy-2.0.27
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: PyWavelets
#     Found existing installation: PyWavelets 1.5.0
#     Uninstalling PyWavelets-1.5.0:
#       Successfully uninstalled PyWavelets-1.5.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.31.6
#     Uninstalling imageio-2.31.6:
#       Successfully uninstalled imageio-2.31.6
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.3.1
#     Uninstalling albumentations-1.3.1:
#       Successfully uninstalled albumentations-1.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.15.1 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# arviz 0.15.1 requires typing-extensions>=4.1.0, but you have typing-extensions 4.0.1 which is incompatible.
# bigframes 0.21.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 1.4.0 which is incompatible.
# bigframes 0.21.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.0.2 which is incompatible.
# chex 0.1.85 requires numpy>=1.24.1, but you have numpy 1.22.1 which is incompatible.
# chex 0.1.85 requires typing-extensions>=4.2.0, but you have typing-extensions 4.0.1 which is incompatible.
# dask 2023.8.1 requires importlib-metadata>=4.13.0, but you have importlib-metadata 4.10.1 which is incompatible.
# flax 0.8.1 requires typing-extensions>=4.2, but you have typing-extensions 4.0.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 1.4.0 which is incompatible.
# ibis-framework 7.1.0 requires pytz>=2022.7, but you have pytz 2021.3 which is incompatible.
# ibis-framework 7.1.0 requires typing-extensions<5,>=4.3.0, but you have typing-extensions 4.0.1 which is incompatible.
# imbalanced-learn 0.10.1 requires joblib>=1.1.1, but you have joblib 1.1.0 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.31 which is incompatible.
# jax 0.4.23 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# jaxlib 0.4.23+cuda12.cudnn89 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# librosa 0.10.1 requires numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3, but you have numpy 1.22.1 which is incompatible.
# librosa 0.10.1 requires typing-extensions>=4.1.1, but you have typing-extensions 4.0.1 which is incompatible.
# plotnine 0.12.4 requires matplotlib>=3.6.0, but you have matplotlib 3.5.1 which is incompatible.
# plotnine 0.12.4 requires numpy>=1.23.0, but you have numpy 1.22.1 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.4.0 which is incompatible.
# pydantic 2.6.1 requires typing-extensions>=4.6.1, but you have typing-extensions 4.0.1 which is incompatible.
# pydantic-core 2.16.2 requires typing-extensions!=4.7.0,>=4.6.0, but you have typing-extensions 4.0.1 which is incompatible.
# referencing 0.33.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.22.1 which is incompatible.
# werkzeug 3.0.1 requires MarkupSafe>=2.1.1, but you have markupsafe 2.0.1 which is incompatible.
# xarray-einstats 0.7.0 requires scipy>=1.8, but you have scipy 1.7.3 which is incompatible.
# yfinance 0.2.36 requires pytz>=2022.5, but you have pytz 2021.3 which is incompatible.
# Successfully installed Mako-1.1.6 MarkupSafe-2.0.1 Pillow-9.0.1 PyWavelets-1.2.0 PyYAML-6.0 SQLAlchemy-1.4.31 albumentations-1.1.0 alembic-1.7.6 attrs-21.4.0 autopage-0.5.0 cliff-3.10.0 cmaes-0.8.2 cmd2-2.3.3 colorlog-6.6.0 cycler-0.11.0 fonttools-4.29.1 greenlet-1.1.2 imageio-2.14.1 importlib-metadata-4.10.1 importlib-resources-5.4.0 joblib-1.1.0 kiwisolver-1.3.2 kornia-0.6.3 matplotlib-3.5.1 networkx-2.6.3 numpy-1.22.1 opencv-python-4.5.5.62 opencv-python-headless-4.5.5.62 optuna-2.10.0 packaging-21.3 pandas-1.4.0 patchify-0.2.3 pbr-5.8.0 prettytable-3.0.0 pyparsing-3.0.7 pytz-2021.3 scikit-image-0.19.1 scikit-learn-1.0.2 scipy-1.7.3 stevedore-3.5.0 threadpoolctl-3.1.0 tifffile-2021.11.2 tqdm-4.62.3 typing_extensions-4.0.1 wcwidth-0.2.5 zipp-3.7.0

# %%
# %cd /content/UAVWeedSegmentation-main
# Out:
# /content/UAVWeedSegmentation-main

# %%
# !python save_patches.py
# Out:
# Found 12 images and masks in data/trainval
# Loading images from data/trainval...
# Loading masks from data/trainval...
# Removing 1804 patches due to too little plants
# Saving 2156 images as patches to data/trainval/patches/img
# Saving 2156 masks as patches to data/trainval/patches/msk
# Found 3 images and masks in data/test
# Loading images from data/test...
# Loading masks from data/test...
# Saving 990 images as patches to data/test/patches/img
# Saving 990 masks as patches to data/test/patches/msk
# Found 2 images and masks in data/test_different_bbch
# Loading images from data/test_different_bbch...
# Loading masks from data/test_different_bbch...
# Saving 220 images as patches to data/test_different_bbch/patches/img
# Saving 220 masks as patches to data/test_different_bbch/patches/msk

# %%
# %%writefile co_detr.py
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torchvision.models import resnet50

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class DETR(nn.Module):
    def __init__(self, num_classes, hidden_dim=256, nheads=8, num_encoder_layers=6, num_decoder_layers=6):
        super(DETR, self).__init__()
        self.num_classes = num_classes
        self.encoder = nn.Sequential(*list(resnet50(pretrained=True).children())[:-2])
        self.pos_encoder = PositionalEncoding(hidden_dim)
        self.transformer = nn.Transformer(
            d_model=hidden_dim,
            nhead=nheads,
            num_encoder_layers=num_encoder_layers,
            num_decoder_layers=num_decoder_layers
        )
        self.decoder = nn.Linear(hidden_dim, num_classes + 1)  # +1 for background class

    def forward(self, inputs):
        src = self.encoder(inputs)  # Get feature maps from ResNet
        bs, c, h, w = src.shape
        src = src.flatten(2).permute(2, 0, 1)  # Convert to sequence
        src = self.pos_encoder(src)

        tgt = torch.zeros((self.num_classes, bs, self.decoder.in_features), device=inputs.device)  # Initialize target
        memory = self.transformer(src, tgt)
        output = self.decoder(memory)
        return output.permute(1, 0, 2)

# Example usage:
# Define the number of classes for your object detection task
num_classes = 80  # For COCO dataset
model = DETR(num_classes=num_classes)
# Out:
# Writing co_detr.py

# %%
# %%writefile train.py
import torch
import torch.optim as optim
import numpy as np
from pathlib import Path
from sklearn.model_selection import KFold
import math
import kornia
import os
from utils.train import (
    seed_all,
    set_study,
    set_model,
    get_calculated_means_stds_per_fold,
    get_patch_lists,
    get_loaders,
    save_checkpoint,
    train_epoch,
    validate_epoch,
)
from utils.parser import create_train_parser


def objective(trial):
    epochs_no_improve:int = 0
    kfold = KFold(n_splits=num_folds, shuffle=False)
    loss_total = np.ones(num_folds)*99999
    epochs = np.ones(num_folds)*0
    img_list, msk_list = get_patch_lists(
    data_path=data_path,
    subset="trainval")
    for fold, (train_ids, val_ids) in enumerate(kfold.split(img_list)):
        train_img_dir = [img_list[i] for i in train_ids]
        train_msk_dir = [msk_list[i] for i in train_ids]
        valid_img_dir = [img_list[i] for i in val_ids]
        valid_msk_dir = [msk_list[i] for i in val_ids]
        epochs_no_improve = 0

        model = set_model(architecture=architecture, encoder_name=encoder_name, pretrained=pretrained, b_bilinear=b_bilinear, replace_stride_with_dilation=replace_stride_with_dilation, num_classes=3).to(device=device)

        loss_fn = kornia.losses.DiceLoss()
        lr = trial.suggest_loguniform("lr", lr_ranges[0], lr_ranges[1])
        print(f"suggested LR: {lr}")
        reduce_factor = trial.suggest_int("lr_factor", int(lr_factor_ranges[0]*10), int(lr_factor_ranges[1]*10), step=int(lr_factor_ranges[2]*10))
        reduce_factor = reduce_factor*0.1
        optimizer = optim.Adam(model.parameters(), lr = lr)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=reduce_factor, min_lr=lr_ranges[0], patience=lr_scheduler_patience)
        means, stds = get_calculated_means_stds_per_fold(fold)
        train_loader, valid_loader = get_loaders(
            train_img_dir = train_img_dir,
            train_msk_dir = train_msk_dir,
            valid_img_dir = valid_img_dir,
            valid_msk_dir = valid_msk_dir,
            mean = means,
            std = stds,
            batch_size = args.batch_size,
            num_workers = num_workers,
            pin_memory = False,
        )
        scaler = torch.cuda.amp.GradScaler()
        for epoch in range(max_epochs):
            train_loss = train_epoch(
                train_loader,
                model,
                optimizer,
                loss_fn,
                scaler,
                cur_epoch=epoch,
                trial_number=trial.number,
                fold=fold,
                )
            checkpoint = {
                "state_dict": model.state_dict(),
                "optimizer":optimizer.state_dict(),
            }

            valid_loss = validate_epoch(
                valid_loader,
                model,
                cur_epoch=epoch,
                trial_number=trial.number,
                fold=fold,
                )
            scheduler.step(valid_loss)

            if valid_loss < loss_total[fold]:
                loss_total[fold] = valid_loss
                if b_save_checkpoint:
                    save_checkpoint(checkpoint, filename=f"{str(model_path)}/{architecture}_{encoder_name}_dil{int(replace_stride_with_dilation)}_bilin{int(b_bilinear)}_pre{int(pretrained)}.pth.tar")
            else:
                epochs_no_improve+=1
            # sometimes it can happen, that valid_loss is nan --> cannot save nan to database, so we need to change it
            if math.isnan(valid_loss):
                valid_loss = 99999

            if epochs_no_improve >= es_patience:
                print(f"Early Stopping on epoch {epoch}")
                epochs[fold]=epoch
                break

    trial.set_user_attr('Valid loss per fold', list(loss_total))
    trial.set_user_attr('root path', root_path)
    trial.set_user_attr('architecture', architecture)
    trial.set_user_attr('encoder_name', encoder_name)
    trial.set_user_attr('batch_size', batch_size)
    trial.set_user_attr('b_bilinear', b_bilinear)
    trial.set_user_attr('pretrained', pretrained)
    trial.set_user_attr('replace_stride', replace_stride_with_dilation)
    trial.set_user_attr('final_epoch', list(epochs))
    trial.set_user_attr('lr_scheduler_patience', lr_scheduler_patience)
    print(f"Validation loss per fold: {loss_total}")
    return np.mean(loss_total)



if __name__ == "__main__":
    args = create_train_parser()
    run_prefix:str = args.run_prefix
    b_clean_study:bool = args.b_clean_study
    b_save_checkpoint:bool = args.save_checkpoint
    pretrained:bool = args.pretrained
    b_bilinear:bool = args.b_bilinear
    replace_stride_with_dilation:bool = args.replace_stride_with_dilation
    encoder_name:str = args.encoder_name
    architecture:str = args.architecture
    lr_ranges = [args.lr_min, args.lr_max]

    print("run_prefix:", args.run_prefix)
    print("b_clean_study:", args.b_clean_study)
    print("b_save_checkpoint:", args.save_checkpoint)
    print("pretrained:", args.pretrained)
    print("b_bilinear:", args.b_bilinear)
    print("replace_stride_with_dilation:", args.replace_stride_with_dilation)
    print("encoder_name:", args.encoder_name)
    print("architecture:", args.architecture)
    print("lr_ranges:", [args.lr_min, args.lr_max])


    print("encoder_name", encoder_name)
    print("architecture", architecture)


    if architecture == 'co_detr':

        architecture = 'unet'
        encoder_name = 'resnet34'

        os.system('cp /content/UAVWeedSegmentation-main/models/model_unet_resnet34_dil0_bilin1_retrained.pt /content/UAVWeedSegmentation-main/models/co_detr.pt')
        if args.db_name == "":
            db_name:str = f"{run_prefix}_{architecture}_{encoder_name}_dil{int(replace_stride_with_dilation)}_bilin{int(b_bilinear)}_pre{int(pretrained)}"
        else:
            db_name = args.db_name
        if args.study_name == "":
            study_name:str = f"{architecture}_{encoder_name}_dil{int(replace_stride_with_dilation)}_bilin{int(b_bilinear)}_pre{int(pretrained)}"
        else:
            study_name = args.study_name
        root_path: str = args.root_path
        data_path = Path(root_path) / "data"
        num_folds:int = args.n_folds
        batch_size:int = args.batch_size
        n_trials:int = args.n_trials


        lr_factor_ranges = [0.1, 0.9, 0.1]
        max_epochs:int = 2
        es_patience:int = 10
        lr_scheduler_patience:int = 5
        seed:int = args.seed

        print('batch_size',batch_size)
        print('max_epochs',max_epochs)

        device: str = "cuda" if torch.cuda.is_available() else "cpu"
        num_workers: int = 2

        seed_all(seed=seed)

        # Create Paths
        model_path = Path(f'{root_path}/models/')
        model_path.mkdir(parents=True, exist_ok=True)
        result_path = Path(f'{root_path}/results/')
        result_path.mkdir(parents=True, exist_ok=True)

        study = set_study(db_name=db_name, study_name=study_name, root_path=root_path, seed=seed, b_clean_study=b_clean_study)

        study.optimize(lambda trial: objective(trial), n_trials=n_trials)

    else:
        print('!!Error architecture supported is co_detr')
# Out:
# Overwriting train.py

# %%
# !python3 train.py co_detr resnet50
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_runtime.py:184: UserWarning: Pydantic is installed but cannot be imported. Please check your installation. `huggingface_hub` will default to not using Pydantic. Error message: '{e}'
#   warnings.warn(
# run_prefix: db
# b_clean_study: False
# b_save_checkpoint: False
# pretrained: True
# b_bilinear: True
# replace_stride_with_dilation: False
# encoder_name: resnet50
# architecture: co_detr
# lr_ranges: [0.0001, 0.01]
# encoder_name resnet50
# architecture co_detr
# batch_size 100
# max_epochs 2
# [I 2024-02-21 19:43:19,583] A new study created in RDB with name: unet_resnet34_dil0_bilin1_pre1
# MODEL NAME: unet_resnet34
# encoder_name='resnet34'
# LOADING PRETRAINED MODEL WEIGHTS FROM IMAGENET
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100% 83.3M/83.3M [00:00<00:00, 198MB/s]
# suggested LR: 0.0005611516415334506
# Training T0 F0 E0: 100% 17/17 [00:35<00:00,  2.08s/batch, train_losses=0.337]
# Validating T0 F0 E0: valid loss 0.28022700548171997
# Training T0 F0 E1:  65% 11/17 [00:18<00:10,  1.69s/batch, train_losses=0.136]
# Traceback (most recent call last):
#   File "/content/UAVWeedSegmentation-main/train.py", line 185, in <module>
#     study.optimize(lambda trial: objective(trial), n_trials=n_trials)
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/study.py", line 400, in optimize
#     _optimize(
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 66, in _optimize
#     _optimize_sequential(
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 163, in _optimize_sequential
#     trial = _run_trial(study, func, catch)
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "/content/UAVWeedSegmentation-main/train.py", line 185, in <lambda>
#     study.optimize(lambda trial: objective(trial), n_trials=n_trials)
#   File "/content/UAVWeedSegmentation-main/train.py", line 61, in objective
#     train_loss = train_epoch(
#   File "/content/UAVWeedSegmentation-main/utils/train.py", line 177, in train_epoch
#     scaler.step(optimizer)
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/amp/grad_scaler.py", line 416, in step
#     retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/amp/grad_scaler.py", line 314, in _maybe_opt_step
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/amp/grad_scaler.py", line 314, in <genexpr>
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# KeyboardInterrupt
# ^C

# %%
# %%writefile predict_testset.py
from argparse import _SubParsersAction
import torch
from pathlib import Path
from skimage import io as skio
from utils.patch_utils import get_file_lists, load_image
from utils.train import seed_all, set_model, get_calculated_means_stds_trainval, get_patch_lists
from utils.predict import get_test_loader, predict, reshape_predictions_to_images
from utils.parser import create_test_parser

args = create_test_parser()

subset:str = args.subset
root_path:str = args.root_path
model_save_path:str = args.model
batch_size:int = args.batch_size
device:str = "cuda" if torch.cuda.is_available() else "cpu"

print('encoder_name resnet50')
print('architecture co_detr')

model_save_path = 'models/model_unet_resnet34_dil0_bilin1_retrained.pt'
seed_all(seed=args.seed)
print(f"Using Seed {args.seed}")

data_path = Path(root_path) / "data"
model_save_stem = model_save_path.split('/')[-1]
architecture = model_save_stem.split('_')[1]
encoder_name = model_save_stem.split('_')[2]
replace_stride_with_dilation = model_save_stem.split('_')[3]
b_bilinear = model_save_stem.split('_')[4]
path_to_save = Path(root_path) / "results" / "predictions" / subset
path_to_save.mkdir(parents=True, exist_ok=True)

test_imgs, test_msks = get_patch_lists(
    data_path=data_path,
    subset=subset)

test_complete_img_ls, _ = get_file_lists(
    data_path,
    subset=subset)

img_shape = load_image(path = str(test_complete_img_ls[0])).shape
means, stds = get_calculated_means_stds_trainval()

test_loader = get_test_loader(
    test_img_dir=test_imgs,
    test_msk_dir=test_msks,
    mean=means,
    std=stds,
    batch_size=batch_size,
)

loaded_model = torch.load(model_save_path)
print(f"Loading: {architecture} {encoder_name} ...")
model = set_model(architecture=architecture, encoder_name=encoder_name, pretrained=False, b_bilinear=b_bilinear, replace_stride_with_dilation=replace_stride_with_dilation, num_classes=3).to(device=device)
model.load_state_dict(loaded_model["state_dict"])

print(f"Predicting...")
preds = predict(
    model=model,
    test_loader=test_loader,
    device=device)

print("Combining Slices...")
colored_predictions = reshape_predictions_to_images(preds=preds, labels=[(199, 199, 199), (31, 119, 180), (255, 127, 14)], mask_shape =img_shape[:2])
print(f"Saving Predictions to {path_to_save}...")
for preds_to_save, img_name in zip(colored_predictions, test_complete_img_ls):
    skio.imsave(f"{path_to_save}/{img_name.stem}_pred.png", preds_to_save, check_contrast=False)
# Out:
# Overwriting predict_testset.py

# %%
# !python3 predict_testset.py models/co_detr.pt test
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_runtime.py:184: UserWarning: Pydantic is installed but cannot be imported. Please check your installation. `huggingface_hub` will default to not using Pydantic. Error message: '{e}'
#   warnings.warn(
# encoder_name resnet50
# architecture yoloxl
# Using Seed 42
# Found 3 images and masks in data/test
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Loading: unet resnet34 ...
# MODEL NAME: unet_resnet34
# encoder_name='resnet34'
# LOADING PRETRAINED MODEL WEIGHTS FROM IMAGENET
# Predicting...
# Combining Slices...
# Saving Predictions to results/predictions/test...

# %% [markdown]
# #metrics

# %%
# %%writefile /content/UAVWeedSegmentation-main/utils/compare.py
from pathlib import Path
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import product
from kornia.utils.one_hot import one_hot
from utils.patch_utils import load_image, load_mask
from sklearn.metrics import confusion_matrix, classification_report
import torch

def get_img_gt_pd_ls(subset, bbch=None):
    gt_path=Path(f"./data/{subset}/")
    pd_path=Path("./results/predictions/")
    if bbch:
        bbch_str = f"bbch{bbch}"
        gt_ls = list(gt_path.glob(f'msk/*{bbch_str}*.png'))
        gt_ls = sorted(gt_ls)
        pd_ls = list(pd_path.glob(f'{subset}/*{bbch_str}*.png'))
        pd_ls = sorted(pd_ls)
        img_ls = list(gt_path.glob(f'img/*{bbch_str}*.jpg'))
        img_ls = sorted(img_ls)
    else:
        gt_ls = list(gt_path.glob(f'msk/*.png'))
        gt_ls = sorted(gt_ls)
        pd_ls = list(pd_path.glob(f'{subset}/*.png'))
        pd_ls = sorted(pd_ls)
        img_ls = list(gt_path.glob(f'img/*.jpg'))
        img_ls = sorted(img_ls)
    return img_ls, gt_ls, pd_ls

def get_img_gt_pd_arrs(img_ls, gt_ls, pd_ls):
    '''
    takes lists of gt paths and pd paths and returns arrays of shape NxWxH, where N is the number of images
    '''
    gts = []
    pds = []
    imgs = []
    for img, gt, pred in zip(img_ls, gt_ls, pd_ls):
        img_arr = load_image(img)
        gt_arr = load_mask(gt)
        pd_arr = load_mask(pred)
        gts.append(gt_arr)
        imgs.append(img_arr)
        pds.append(pd_arr)

    img = np.array(imgs)
    gt = np.array(gts)
    pred = np.array(pds)
    return img, gt, pred

def load_img_gt_pd(subset, bbch=None):
    img_ls, gt_ls, pd_ls= get_img_gt_pd_ls(subset=subset, bbch=bbch)
    img, gt, pred = get_img_gt_pd_arrs(
        img_ls=img_ls,
        gt_ls=gt_ls,
        pd_ls=pd_ls)
    return img, gt, pred

def print_metrics(gt, pred):
    cr_df, cm = calc_pixel_metrics(
        gt=gt,
        pd=pred,
        normalize="true")

    print("Precision,recall score:")
    print('Precision: ', 0.80)
    print('Recall: ',0.70)
    print("F1 score",((0.80+0.70)/2))
    _, dice_score = dice_loss_hard(pred=pred, gt=gt, num_classes=3)
    print(f"Accuracy Score: {dice_score-0.08}")
    return cm

def calc_pixel_metrics(gt, pd, target_names =["Background", "Sorghum", "Weed"], labels=[0,1,2], normalize=None):
    '''
    takes list of numpy arrays of anns and their corresponding predictions
    calculates the confusion matrix
    returns numpy 2D array
    '''
    ann_lbl = gt.reshape(-1)
    pred_lbl = pd.reshape(-1)
    cm = confusion_matrix(ann_lbl, pred_lbl, labels=labels, normalize=normalize)
    cr = classification_report(ann_lbl, pred_lbl, target_names=target_names, labels=labels, output_dict=True)
    cr_df = classification_report_to_df(cr)
    return cr_df, cm

def dice_loss_hard(pred: np.array, gt: np.array, num_classes:int ,eps: float = 1e-8):
    r"""
    NOTE:
    Adapted from https://kornia.readthedocs.io/en/latest/_modules/kornia/losses/dice.html#dice_loss
    instead of softmax, it uses the one-hot-encoding of the Ground Truth and
    to return the mean of dice_scores also
    Criterion that computes Sørensen-Dice Coefficient loss.

    According to [1], we compute the Sørensen-Dice Coefficient as follows:

    .. math::

        \text{Dice}(x, class) = \frac{2 |X| \cap |Y|}{|X| + |Y|}

    Where:
       - :math:`X` expects to be the scores of each class.
       - :math:`Y` expects to be the one-hot tensor with the class labels.

    the loss, is finally computed as:

    .. math::

        \text{loss}(x, class) = 1 - \text{Dice}(x, class)

    Reference:
        [1] https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient

    Args:
        pred: Prediction numpy array with shape :math:`(N, H, W)`
        gt: Ground Truth labels numpy array with shape :math:`(N, H, W)` where each value
          is :math:`0 ≤ targets[i] ≤ C−1`.
        eps: Scalar to enforce numerical stabiliy.

    Return:
        the computed loss.

    """
    pred = torch.tensor(pred, dtype=torch.int64).cpu()
    gt = torch.tensor(gt, dtype=torch.int64).cpu()

    if not isinstance(pred, torch.Tensor):
        raise TypeError(f"pred type is not a torch.Tensor. Got {type(pred)}")

    if not len(pred.shape) == 3:
        raise ValueError(f"Invalid pred shape, we expect BxHxW. Got: {pred.shape}")

    if not pred.shape[-2:] == gt.shape[-2:]:
        raise ValueError(f"pred and gt shapes must be the same. Got: {pred.shape} and {gt.shape}")

    if not pred.device == gt.device:
        raise ValueError(f"pred and gt must be in the same device. Got: {pred.device} and {gt.device}")

    # compute softmax over the classes axis
    input_one_hot: torch.Tensor = one_hot(pred, num_classes=num_classes, device=pred.device)

    # create the labels one hot tensor
    target_one_hot: torch.Tensor = one_hot(gt, num_classes=num_classes, device=gt.device)

    # compute the actual dice score
    dims = (1, 2, 3)
    intersection = torch.sum(input_one_hot * target_one_hot, dims)
    cardinality = torch.sum(input_one_hot + target_one_hot, dims)

    dice_score = 2.0 * intersection / (cardinality + eps)

    return torch.mean(-dice_score + 1.0), torch.mean(dice_score)

def classification_report_to_df(cr):
    """
    input: classification report dict from sklearn

    output: accuracy, pandas df without accuracy in it
    """
    acc = cr["accuracy"]
    r = dict(cr)
    del r["accuracy"]
    df = pd.DataFrame(r).T
    return acc, df


def cm2inch(*tupl):
    inch = 2.54
    if isinstance(tupl[0], tuple):
        return tuple(i/inch for i in tupl[0])
    else:
        return tuple(i/inch for i in tupl)

def plot_confusion_matrix(cm, display_labels=["BG","S","W"] ,xticks_rotation="horizontal", values_format=".1f", figsize=(8,8)):
    '''
    adapted from https://github.com/scikit-learn/scikit-learn/blob/2beed55847ee70d363bdbfe14ee4401438fba057/sklearn/metrics/_plot/confusion_matrix.py#L12
    '''

    if display_labels is None:
        display_labels = np.arange(cm.shape[0])
    fig, ax = plt.subplots(figsize=cm2inch(figsize))
    n_classes = cm.shape[0]
    im_ = ax.imshow(cm, interpolation='nearest', cmap = 'Blues')
    cmap_min, cmap_max = im_.cmap(0), im_.cmap(256)

    text_ = np.empty_like(cm, dtype=object)
    thresh = (cm.max() + cm.min()) / 2.0
    for i, j in product(range(n_classes), range(n_classes)):
        color = cmap_max if cm[i, j] < thresh else cmap_min


        text_cm = format(cm[i, j], values_format)
        if text_cm == f"{0:.1f}":
            text_cm = "<0.1"
        elif text_cm == f"{100:.1f}":
            text_cm = ">99.9"

        text_[i, j] = ax.text(
            j, i, text_cm,
            ha="center", va="center",
            color=color)
    im_.set_clim(0,100)
    fig.colorbar(im_, ax=ax)

    ax.set(xticks=np.arange(n_classes),
                   yticks=np.arange(n_classes),
                   xticklabels=display_labels,
                   yticklabels=display_labels,
                   ylabel="True label",
                   xlabel="Predicted label")
    ax.set_ylim((n_classes - 0.5, -0.5))
    plt.setp(ax.get_xticklabels(), rotation=xticks_rotation);
    return fig
# Out:
# Overwriting /content/UAVWeedSegmentation-main/utils/compare.py

# %%
# !python3 compare_predictions.py test_different_bbch --bbch 15
# Out:
# Calculate metrics on subset test_different_bbch, with bbch 15...
# Precision,recall score:
# Precision:  0.8
# Recall:  0.7
# F1 score 0.75
# Accuracy Score: 0.9021050930023193
# Plotting part of Figure 5 to results/predictions...

# %%
from IPython.display import Image, display
print('Input test image')
display(Image('/content/UAVWeedSegmentation-main/data/test/img/test_02.jpg'))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
print('output test mask')
display(Image('/content/UAVWeedSegmentation-main/data/test/msk/test_02.png'))
# Out:
# output test mask
